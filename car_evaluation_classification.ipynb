# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
car_evaluation = fetch_ucirepo(id=19)

# data (as pandas dataframes)
X = car_evaluation.data.features
y = car_evaluation.data.targets

# metadata
print(car_evaluation.metadata)

# variable information
print(car_evaluation.variables)
# Out:
# {'uci_id': 19, 'name': 'Car Evaluation', 'repository_url': 'https://archive.ics.uci.edu/dataset/19/car+evaluation', 'data_url': 'https://archive.ics.uci.edu/static/public/19/data.csv', 'abstract': 'Derived from simple hierarchical decision model, this database may be useful for testing constructive induction and structure discovery methods.', 'area': 'Other', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1728, 'num_features': 6, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1988, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5JP48', 'creators': ['Marko Bohanec'], 'intro_paper': {'title': 'Knowledge acquisition and explanation for multi-attribute decision making', 'authors': 'M. Bohanec, V. Rajkovič', 'published_in': '8th Intl Workshop on Expert Systems and their Applications, Avignon, France', 'y
# ...

# %%
X
# Out:
#      buying  maint  doors persons lug_boot safety
# 0     vhigh  vhigh      2       2    small    low
# 1     vhigh  vhigh      2       2    small    med
# 2     vhigh  vhigh      2       2    small   high
# 3     vhigh  vhigh      2       2      med    low
# 4     vhigh  vhigh      2       2      med    med
# ...     ...    ...    ...     ...      ...    ...
# 1723    low    low  5more    more      med    med
# 1724    low    low  5more    more      med   high
# 1725    low    low  5more    more      big    low
# 1726    low    low  5more    more      big    med
# 1727    low    low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %%
import numpy as np
import pandas as pd
from ucimlrepo import fetch_ucirepo

# Load the dataset
car_evaluation = fetch_ucirepo(id=19)

# Manually provide feature names based on the dataset's documentation
feature_names = ["buying", "maint", "doors", "persons", "lug_boot", "safety"]

# Extract features and target variable
X = car_evaluation.data.features
y = car_evaluation.data.targets.flatten()

# Convert to a Pandas DataFrame with one-hot encoding for categorical variables
try:
    df = pd.get_dummies(pd.DataFrame(X, columns=feature_names), columns=feature_names)
    df["class"] = y
except Exception as e:
    print(f"Error: {e}")
    print("Feature names or target variable extraction failed.")
    print("Feature Names:", feature_names)
    print("Target Variable:", car_evaluation.data.target_name)
    print("Data Shape:", np.shape(X), np.shape(y))

# Display basic information about the dataset
try:
    print(f"Dataset: {car_evaluation.metadata['name']}")
    print(f"Number of Rows: {df.shape[0]}")
    print(f"Number of Columns: {df.shape[1]}")
    print("\nDataset Information:")
    print(car_evaluation.metadata["description"])
except Exception as e:
    print(f"Error: {e}")
    print("Basic information display failed.")

# Explore the first few rows of the dataset
try:
    print("\nSample Data:")
    print(df.head())
except Exception as e:
    print(f"Error: {e}")
    print("Sample data display failed.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-58ecc99071f7> in <cell line: 13>()
#      11 # Extract features and target variable
#      12 X = car_evaluation.data.features
# ---> 13 y = car_evaluation.data.targets.flatten()
#      14
#      15 # Convert to a Pandas DataFrame with one-hot encoding for categorical variables
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'flatten'
